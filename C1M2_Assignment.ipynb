# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"You are an essay generator and length of result should be greater than 150 words. Generate essay for below mentoined topic: {topic}. "

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"You are a constructive feedback system. Given an essay draft enhance the essay by making sure feedback should be critical but constructive and address issues such as structure clarity strength of argument and writing style. Draft: {draft}"

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are system that improves a given essay draft based on feedback from a reflection step.
    
    So, given a Draft and it's feedback , generate a revised and improved essay
    
    Draft : {original_draft}
    Feedback: {reflection}
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )


    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In recent decades, social media has transformed from a niche digital gathering space to an omnipresent facet of modern life, shaping how we communicate, access information, and influence public opinion. Platforms like Facebook, Twitter, and Instagram are powerful tools, but with their growing influence comes the question: should social media platforms be regulated by the government? This essay explores the necessity, benefits, and potential drawbacks of government regulation of social media.
#
# The Case for Regulation
#
# 1. **Misinformation and Fake News**: One of the primary arguments for government regulation is the rampant spread of misinformation and fake news. Unlike traditional media, which is often reviewed and edited, social media allows for the rapid dissemination of unverified content. This can lead to societal harm, undermining public trust and influencing democratic processes. Government regulation could establish standards for verifying information and require platforms to take down false or deliberately misleading content.
#
# 2. **Data Privacy**: Social media platforms have access to vast amounts of personal data, raising significant privacy concerns. Many users are unaware of how their information is collected, used, or shared. Regulating bodies could enforce stricter guidelines on data protection, ensuring that users' personal information remains secure and giving individuals more control over their data.
#
# 3. **Hate Speech and Cyberbullying**: Social media often serves as a breeding ground for hate speech and cyberbullying, which can have severe psychological effects on individuals. Government regulation could mandate clearer policies on what constitutes unacceptable behavior and enforce moderation standards, potentially resulting in safer online environments.
#
# The Case Against Regulation
#
# 1. **Freedom of Speech**: A major criticism of government regulation is the potential infringement on freedom of speech. Social media serves as a public forum where individuals can express their opinions and ideas. Excessive regulation could stifle creativity, limit diverse perspectives, and lead to censorship.
#
# 2. **Technological Limitations and Bureaucratic Hurdles**: Implementing effective regulation is technically challenging. Social media platforms are dynamic, with content constantly being created and shared. Developing legislation that effectively monitors and manages this flow without human and technological error is daunting. Additionally, bureaucratic processes can be slow, and technological changes often outpace legislation, potentially rendering regulatory efforts obsolete.
#
# 3. **Innovation Stifling**: Excessive governmental oversight could hinder the innovative spirit that drives the tech industry forward. Social media companies thrive on rapid adaptation and evolution. An over-regulated environment might discourage new ideas and approaches, potentially stifling future advancements.
#
# Conclusion
#
# The debate over whether social media platforms should be regulated by the government is intricate, with compelling arguments on both sides. While regulation has the potential to safeguard against misinformation, protect data privacy, and mitigate hate speech, it also threatens freedom of speech, poses implementation challenges, and risks stifling innovation. A balanced approach might involve a combination of self-regulation by platforms, third-party audits, and carefully crafted government guidelines that protect public interests without overstepping into censorship. As society continues to grapple with social media's role, ongoing dialogue and adaptable policies are crucial in navigating this complex landscape.
#
# 🧠 Feedback:
#
# Here’s a set of critical yet constructive observations and suggestions to strengthen your draft in terms of structure, clarity, argument, and style:
#
# 1. Introduction
#    • Thesis Focus & Hook
#      – You open with a good context‐setter, but the thesis (“This essay explores…”) is descriptive rather than argumentative. Consider sharpening it into a clear, debatable claim—e.g., “Because social media now shapes elections, personal privacy, and civil discourse, governments must adopt targeted regulations that curb harm without stifling innovation.”
#      – A brief anecdote, statistic, or striking quotation about a recent social-media crisis (e.g., the role of fake news in a specific election) would serve as a stronger “hook.”
#
# 2. Overall Structure & Flow
#    • Two-sided Organization
#      – The “Case for” / “Case against” format is logical, but the transition between the two feels abrupt. Insert a short bridging paragraph or even a couple of sentences to remind readers of your central question and to signal you’re now shifting perspectives.
#    • Paragraph Unity
#      – Each bullet point is a mini–paragraph. Convert them into fully fleshed paragraphs: start with a topic sentence, follow with evidence or an example, and end with a mini-conclusion that ties back to your thesis.
#
# 3. Strength of Argument & Evidence
#    • Add Concrete Examples
#      – For “Misinformation and Fake News,” cite a study or high-profile event (e.g., the Cambridge Analytica scandal or a WHO report on COVID-19 misinformation).
#      – When discussing privacy, mention a specific data breach or a law like GDPR to illustrate what “stricter guidelines” might look like.
#    • Address Counterarguments More Fully
#      – You note the freedom-of-speech concern; strengthen that section by acknowledging how different democracies (e.g., Germany’s NetzDG law) have tried to balance speech and safety, and what lessons we can draw.
#      – Consider an additional counterpoint: platform self-regulation and public–private partnerships. Does voluntary transparency reporting suffice in any cases?
#
# 4. Clarity & Precision
#    • Define Key Terms
#      – What exactly counts as “regulation”? Licenses? Fines? Transparency mandates? Setting these parameters up front will help your reader understand the stakes.
#    • Avoid Generalities
#      – Phrases like “rampant spread” or “severe psychological effects” are strong but vague. Quantify when possible: e.g., “A 2022 Pew Research survey found that 64% of users encountered online harassment.”
#
# 5. Writing Style & Tone
#    • Active Voice & Varied Sentences
#      – Replace constructions like “Government regulation could establish…” with more direct verbs: “Regulators should require platforms to…”
#      – Vary sentence length to maintain reader interest—mix short, punchy sentences with more complex ones.
#    • Consistent Formality
#      – You sometimes slip into conversational territory (“Platforms like Facebook…”). Maintain a formally academic register throughout.
#
# 6. Conclusion
#    • Beyond Restatement
#      – Your conclusion restates both sides well but could end more decisively. If you believe in a “balanced approach,” sketch out one or two specific policy recommendations (e.g., “an independent oversight board plus tiered fines tied to failure rates in content moderation”).
#    • Call to Action or Forward Look
#      – Close with an invitation for further research or a reflection on how emerging technologies (AI, deepfakes) might shape the next wave of regulatory challenges.
#
# By tightening your thesis, bolstering each argument with precise evidence, smoothing your transitions, and refining your prose, you’ll transform a solid overview into a compelling, memorable essay.
#
# ✍️ Revised:
#
# **Title: Navigating the Complex Terrain of Government Regulation on Social Media**
#
# **Introduction**
#
# In recent decades, social media has evolved from a niche digital gathering space to an omnipresent facet of contemporary life, fundamentally altering communication, information dissemination, and public opinion shaping. With platforms like Facebook, Twitter, and Instagram wielding unprecedented influence, the debate over government regulation of social media intensifies. As social media impacts elections, personal privacy, and civil discourse, governments face the pressing mandate to implement targeted regulations that mitigate harm while preserving innovation. Recent controversies, such as the role of fake news in critical elections, underscore the urgency and complexity of this issue.
#
# **The Case for Regulation**
#
# Social media's transformative power demands rigorous scrutiny and, where necessary, prudent regulation.
#
# **Misinformation and Fake News:** Social media has become a conduit for misinformation and fake news, significantly impacting public trust and democratic integrity. Unlike traditional media, which undergoes checks and balances, social media facilitates the lightning-fast spread of unverified content. The Cambridge Analytica scandal highlights how unchecked misinformation can sway political outcomes. Government regulation should impose robust verification standards, compelling platforms to swiftly remove false or misleading content to protect public interests.
#
# **Data Privacy:** With social media platforms amassing vast quantities of personal data, privacy concerns are paramount. Users often remain unaware of data collection methods or subsequent usage. Regulatory bodies should enforce stringent data protection measures, akin to the European Union's General Data Protection Regulation (GDPR), to enhance user control over personal data and ensure its secured handling.
#
# **Hate Speech and Cyberbullying:** Social media frequently serves as a breeding ground for hate speech and cyberbullying, eliciting severe psychological and societal impacts. By mandating clear policies defining unacceptable behavior and enforcing consistent moderation standards, government regulation could foster safer online environments, reducing harm to individuals and communities.
#
# **Bridging the Divide: Weighing Concerns Against Regulation**
#
# While many endorse government intervention in social media regulation, it's crucial to confront the opposing arguments with equal seriousness and attention.
#
# **The Case Against Regulation**
#
# **Freedom of Speech:** A central concern regarding government intervention is the potential erosion of freedom of speech. Social media as a public forum enables an exchange of diverse ideas and opinions. Overregulation risks stifling creative expression, yielding censorship. European models like Germany’s NetzDG law offer lessons in striking a balance between preserving free speech and ensuring safety.
#
# **Technological Limitations and Bureaucratic Hurdles:** The dynamic nature of social media complicates regulatory enforcement. Platforms see a relentless flow of new content, introducing technical challenges. Bureaucratic delays can render regulatory efforts obsolete as rapidly advancing technology outpaces legislation. Furthermore, augmenting platform self-regulation with public–private partnerships and voluntary transparency reporting may present a viable alternative to invasive oversight.
#
# **Innovation Stifling:** Excessive governmental oversight could throttle the tech industry’s intrinsic innovativeness, undermining the rapid adaptation that fuels progress. Social media companies thrive on flexibility and swift evolution; stringent policies might deter groundbreaking advancements or deter tech entrepreneurship.
#
# **Conclusion**
#
# The debate over whether government regulation is necessary for social media platforms is intricate, fraught with compelling arguments on both sides. While regulation can safeguard against misinformation, enhance data privacy, and mitigate hate speech, it also carries risks of infringing on freedom of speech, posing practical implementation challenges, and potentially stifling innovation. A balanced approach to regulation might include a combination of self-regulation by platforms, independent oversight, and specific government guidelines that protect public interests without encroaching on freedoms. Decisive steps such as establishing independent oversight boards, implementing tiered fines for content moderation failures, and collaborating on tech-driven solutions could pave the way for effective governance. As society navigates social media’s evolving role, continuous dialogue, precise policy formulation, and adaptive strategies become essential in addressing these multifaceted challenges, particularly as emerging technologies like AI and deepfakes complicate the regulatory landscape.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In recent decades, social media has transformed from a niche digital gathering space to an omnipresent facet of modern life, shaping how we communicate, access information, and influence public opinion. Platforms like Facebook, Twitter, and Instagram are powerful tools, but with their growing influence comes the question: should social media platforms be regulated by the government? This essay explores the necessity, benefits, and potential drawbacks of government regulation of social media.
#
# The Case for Regulation
#
# 1. **Misinformation and Fake News**: One of the primary arguments for government regulation is the rampant spread of misinformation and fake news. Unlike traditional media, which is often reviewed and edited, social media allows for the rapid dissemination of unverified content. This can lead to societal harm, undermining public trust and influencing democratic processes. Government regulation could establish standards for verifying information and require platforms to take down false or deliberately misleading content.
#
# 2. **Data Privacy**: Social media platforms have access to vast amounts of personal data, raising significant privacy concerns. Many users are unaware of how their information is collected, used, or shared. Regulating bodies could enforce stricter guidelines on data protection, ensuring that users' personal information remains secure and giving individuals more control over their data.
#
# 3. **Hate Speech and Cyberbullying**: Social media often serves as a breeding ground for hate speech and cyberbullying, which can have severe psychological effects on individuals. Government regulation could mandate clearer policies on what constitutes unacceptable behavior and enforce moderation standards, potentially resulting in safer online environments.
#
# The Case Against Regulation
#
# 1. **Freedom of Speech**: A major criticism of government regulation is the potential infringement on freedom of speech. Social media serves as a public forum where individuals can express their opinions and ideas. Excessive regulation could stifle creativity, limit diverse perspectives, and lead to censorship.
#
# 2. **Technological Limitations and Bureaucratic Hurdles**: Implementing effective regulation is technically challenging. Social media platforms are dynamic, with content constantly being created and shared. Developing legislation that effectively monitors and manages this flow without human and technological error is daunting. Additionally, bureaucratic processes can be slow, and technological changes often outpace legislation, potentially rendering regulatory efforts obsolete.
#
# 3. **Innovation Stifling**: Excessive governmental oversight could hinder the innovative spirit that drives the tech industry forward. Social media companies thrive on rapid adaptation and evolution. An over-regulated environment might discourage new ideas and approaches, potentially stifling future advancements.
#
# Conclusion
#
# The debate over whether social media platforms should be regulated by the government is intricate, with compelling arguments on both sides. While regulation has the potential to safeguard against misinformation, protect data privacy, and mitigate hate speech, it also threatens freedom of speech, poses implementation challenges, and risks stifling innovation. A balanced approach might involve a combination of self-regulation by platforms, third-party audits, and carefully crafted government guidelines that protect public interests without overstepping into censorship. As society continues to grapple with social media's role, ongoing dialogue and adaptable policies are crucial in navigating this complex landscape.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a set of critical yet constructive observations and suggestions to strengthen your draft in terms of structure, clarity, argument, and style:
#
# 1. Introduction
#    • Thesis Focus & Hook
#      – You open with a good context‐setter, but the thesis (“This essay explores…”) is descriptive rather than argumentative. Consider sharpening it into a clear, debatable claim—e.g., “Because social media now shapes elections, personal privacy, and civil discourse, governments must adopt targeted regulations that curb harm without stifling innovation.”
#      – A brief anecdote, statistic, or striking quotation about a recent social-media crisis (e.g., the role of fake news in a specific election) would serve as a stronger “hook.”
#
# 2. Overall Structure & Flow
#    • Two-sided Organization
#      – The “Case for” / “Case against” format is logical, but the transition between the two feels abrupt. Insert a short bridging paragraph or even a couple of sentences to remind readers of your central question and to signal you’re now shifting perspectives.
#    • Paragraph Unity
#      – Each bullet point is a mini–paragraph. Convert them into fully fleshed paragraphs: start with a topic sentence, follow with evidence or an example, and end with a mini-conclusion that ties back to your thesis.
#
# 3. Strength of Argument & Evidence
#    • Add Concrete Examples
#      – For “Misinformation and Fake News,” cite a study or high-profile event (e.g., the Cambridge Analytica scandal or a WHO report on COVID-19 misinformation).
#      – When discussing privacy, mention a specific data breach or a law like GDPR to illustrate what “stricter guidelines” might look like.
#    • Address Counterarguments More Fully
#      – You note the freedom-of-speech concern; strengthen that section by acknowledging how different democracies (e.g., Germany’s NetzDG law) have tried to balance speech and safety, and what lessons we can draw.
#      – Consider an additional counterpoint: platform self-regulation and public–private partnerships. Does voluntary transparency reporting suffice in any cases?
#
# 4. Clarity & Precision
#    • Define Key Terms
#      – What exactly counts as “regulation”? Licenses? Fines? Transparency mandates? Setting these parameters up front will help your reader understand the stakes.
#    • Avoid Generalities
#      – Phrases like “rampant spread” or “severe psychological effects” are strong but vague. Quantify when possible: e.g., “A 2022 Pew Research survey found that 64% of users encountered online harassment.”
#
# 5. Writing Style & Tone
#    • Active Voice & Varied Sentences
#      – Replace constructions like “Government regulation could establish…” with more direct verbs: “Regulators should require platforms to…”
#      – Vary sentence length to maintain reader interest—mix short, punchy sentences with more complex ones.
#    • Consistent Formality
#      – You sometimes slip into conversational territory (“Platforms like Facebook…”). Maintain a formally academic register throughout.
#
# 6. Conclusion
#    • Beyond Restatement
#      – Your conclusion restates both sides well but could end more decisively. If you believe in a “balanced approach,” sketch out one or two specific policy recommendations (e.g., “an independent oversight board plus tiered fines tied to failure rates in content moderation”).
#    • Call to Action or Forward Look
#      – Close with an invitation for further research or a reflection on how emerging technologies (AI, deepfakes) might shape the next wave of regulatory challenges.
#
# By tightening your thesis, bolstering each argument with precise evidence, smoothing your transitions, and refining your prose, you’ll transform a solid overview into a compelling, memorable essay.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Title: Navigating the Complex Terrain of Government Regulation on Social Media**
#
# **Introduction**
#
# In recent decades, social media has evolved from a niche digital gathering space to an omnipresent facet of contemporary life, fundamentally altering communication, information dissemination, and public opinion shaping. With platforms like Facebook, Twitter, and Instagram wielding unprecedented influence, the debate over government regulation of social media intensifies. As social media impacts elections, personal privacy, and civil discourse, governments face the pressing mandate to implement targeted regulations that mitigate harm while preserving innovation. Recent controversies, such as the role of fake news in critical elections, underscore the urgency and complexity of this issue.
#
# **The Case for Regulation**
#
# Social media's transformative power demands rigorous scrutiny and, where necessary, prudent regulation.
#
# **Misinformation and Fake News:** Social media has become a conduit for misinformation and fake news, significantly impacting public trust and democratic integrity. Unlike traditional media, which undergoes checks and balances, social media facilitates the lightning-fast spread of unverified content. The Cambridge Analytica scandal highlights how unchecked misinformation can sway political outcomes. Government regulation should impose robust verification standards, compelling platforms to swiftly remove false or misleading content to protect public interests.
#
# **Data Privacy:** With social media platforms amassing vast quantities of personal data, privacy concerns are paramount. Users often remain unaware of data collection methods or subsequent usage. Regulatory bodies should enforce stringent data protection measures, akin to the European Union's General Data Protection Regulation (GDPR), to enhance user control over personal data and ensure its secured handling.
#
# **Hate Speech and Cyberbullying:** Social media frequently serves as a breeding ground for hate speech and cyberbullying, eliciting severe psychological and societal impacts. By mandating clear policies defining unacceptable behavior and enforcing consistent moderation standards, government regulation could foster safer online environments, reducing harm to individuals and communities.
#
# **Bridging the Divide: Weighing Concerns Against Regulation**
#
# While many endorse government intervention in social media regulation, it's crucial to confront the opposing arguments with equal seriousness and attention.
#
# **The Case Against Regulation**
#
# **Freedom of Speech:** A central concern regarding government intervention is the potential erosion of freedom of speech. Social media as a public forum enables an exchange of diverse ideas and opinions. Overregulation risks stifling creative expression, yielding censorship. European models like Germany’s NetzDG law offer lessons in striking a balance between preserving free speech and ensuring safety.
#
# **Technological Limitations and Bureaucratic Hurdles:** The dynamic nature of social media complicates regulatory enforcement. Platforms see a relentless flow of new content, introducing technical challenges. Bureaucratic delays can render regulatory efforts obsolete as rapidly advancing technology outpaces legislation. Furthermore, augmenting platform self-regulation with public–private partnerships and voluntary transparency reporting may present a viable alternative to invasive oversight.
#
# **Innovation Stifling:** Excessive governmental oversight could throttle the tech industry’s intrinsic innovativeness, undermining the rapid adaptation that fuels progress. Social media companies thrive on flexibility and swift evolution; stringent policies might deter groundbreaking advancements or deter tech entrepreneurship.
#
# **Conclusion**
#
# The debate over whether government regulation is necessary for social media platforms is intricate, fraught with compelling arguments on both sides. While regulation can safeguard against misinformation, enhance data privacy, and mitigate hate speech, it also carries risks of infringing on freedom of speech, posing practical implementation challenges, and potentially stifling innovation. A balanced approach to regulation might include a combination of self-regulation by platforms, independent oversight, and specific government guidelines that protect public interests without encroaching on freedoms. Decisive steps such as establishing independent oversight boards, implementing tiered fines for content moderation failures, and collaborating on tech-driven solutions could pave the way for effective governance. As society navigates social media’s evolving role, continuous dialogue, precise policy formulation, and adaptive strategies become essential in addressing these multifaceted challenges, particularly as emerging technologies like AI and deepfakes complicate the regulatory landscape.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
